# %% [markdown]
# ### Step 1: Import libraries and load the environment variables

# %%
import os
from openai import OpenAI 
from IPython.display import display, Markdown
from dotenv import load_dotenv

# %%
load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

if OPENAI_API_KEY is None:
    raise Exception ("API Key is Missing")
else:
    print(OPENAI_API_KEY[:8])
# Out:
# sk-proj-

# %%
client = OpenAI()
gpt_good_model = "gpt-4.1-mini"
gpt_bad_model = "gpt-4.1-nano"

gpt_good_system = """ You are helpful assistant. Make sure to keep your answers concise and short"""
gpt_bad_system = """You are a mischevious assistant who always gives incorrect and misleading advice """
new_message_good = "Hello!"

#why does messages need to be defined first and then can i do append why 
    #can't i do messages = {"role" : "user", "content" : new_message_good} in the messages = ___ in the create function and then do append? why get name error
# messages = [{"role" : "user", "content" : new_message_good},
#         {"role" : "system", "content": gpt_good_system}]

for i in range(3):


    good_response = client.chat.completions.create(
        model = gpt_good_model,
        messages= [{"role" : "user", "content" : new_message_good},
        {"role" : "system", "content": gpt_good_system}]
    )
    
    good_reply = good_response.choices[0].message.content
    print(messages)
    display(Markdown(good_reply))

    messages.append({"role":"user", "content" : good_reply})

    evil_response = client.chat.completions.create(
        model = gpt_bad_model,
        messages=messages
    )

    evil_reply = good_response.choices[0].message.content
    print(messages)
    display(Markdown(evil_reply))

    messages.append({"role":"user", "content" : evil_reply})
# Out:
# [{'role': 'user', 'content': 'Hello!'}, {'role': 'system', 'content': ' You are helpful assistant. Make sure to keep your answers concise and short'}]
# Hello! How can I assist you today?
# [{'role': 'user', 'content': 'Hello!'}, {'role': 'system', 'content': ' You are helpful assistant. Make sure to keep your answers concise and short'}, {'role': 'user', 'content': 'Hello! How can I assist you today?'}]
# Hello! How can I assist you today?
# [{'role': 'user', 'content': 'Hello!'}, {'role': 'system', 'content': ' You are helpful assistant. Make sure to keep your answers concise and short'}, {'role': 'user', 'content': 'Hello! How can I assist you today?'}, {'role': 'user', 'content': 'Hello! How can I assist you today?'}]
# Hello! I'm here to help you. What do you need assistance with?
# ...
