# %% [markdown]
# ### Step 1: Import libraries and load the environment variables

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv
from IPython.display import Markdown, display

#What is a kernel?

#dotenv.load_dotenv() is the same as just calling it directly - the function
load_dotenv()

#AttributeError: module 'os' has no attribute 'get_env'  --- what is the difference between module, class, and object, functions?
#the thing in "" is what I named the key in the .env file so its searchign for the value assigned to that variable
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

#[:8] means 0 to 8 of the characters in the api key exclusive so to 0 to 7
if OPENAI_API_KEY is None:
    raise Exception("API Key is missing")
else:
    print(OPENAI_API_KEY[:8])


#Here I'm establishing an object of the OpenAI module
client = OpenAI()
# Out:
# sk-proj-

# %% [markdown]
# #### Step 2: Call the API

# %%
response = client.chat.completions.create(
    model = "gpt-4.1-mini",
    messages = [{
        "role" : "system", "content": "You are an assistant."},
        {"role" : "user", "content": "I am traveling to Spain next week!"}
    ]
)

reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# That’s exciting! Do you need any tips or recommendations for your trip to Spain?

# %%
response1 = client.chat.completions.create(
    model = "gpt-4.1-mini",
    messages = [{
        "role" : "system", "content": "You are an assistant."},
        {"role" : "user", "content": "Where am I traveling to next week?"}]
)

reply1 = response1.choices[0].message.content
display(Markdown(reply1))
# Out:
# I don’t have access to your personal travel plans. Could you please provide more details?

# %%
response2 = client.chat.completions.create(
    model = "gpt-4.1-mini",
    messages = [
        {"role" : "system", "content": "You are an assistant."},
        {"role": "user", "content" : "I am traveling to Spain next week!"},
        {"role" : "assistant", "content": "That’s exciting! Do you need any tips or recommendations for your trip to Spain? Where exactly are you planning to visit?"},
        {"role" : "user", "content": "Where am I traveling to next week?"}
    ]
)

reply2 = response2.choices[0].message.content
display(Markdown(reply2))
# Out:
# You mentioned that you are traveling to Spain next week! Is there anything specific you’d like to know or prepare for your trip?

# %% [markdown]
# ### Lets's do it non-manually

# %%
messages =  [
        {"role" : "system", "content": "You are an assistant."},
        {"role": "user", "content" : "I am traveling to Spain next week!"}]

#the first messages is the parameter in the create function and the second
#messages is the variable we defined above that we are passing as an argument
response3 = client.chat.completions.create(
    model = "gpt-4.1-mini",
    messages = messages
)

reply3 = response3.choices[0].message.content
display(Markdown(reply3))

messages.append({"role" : "assistant", "content": reply3})

print(messages)

#Why can't I do: messages = messages.append({"role" : "user", "content" : "Where am I traveling to next week?"})
messages.append({"role" : "user", "content" : "Where am I traveling to next week?"})

#why cant I do: messages.append(messages.append({"role" : "user", "content" : "Where am I traveling to next week?"}) 
#as the argument for the parameter messsages in teh response4 create function?
#If I do I get this error: BadRequestError: Error code: 400 - {'error': {'message': "Invalid type for 'messages': expected an array of objects, but got null instead.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'invalid_type'}}
#What does this error mean can you explain to me?
response4 = client.chat.completions.create(
    model = "gpt-4.1-mini",
    messages = messages
)

reply4 = response4.choices[0].message.content
display(Markdown(reply4))
# Out:
# That's exciting! Spain is a beautiful country with so much to offer. Do you have any specific cities or regions you'll be visiting? I can help with travel tips, local attractions, food recommendations, or anything else you might need!
# [{'role': 'system', 'content': 'You are an assistant.'}, {'role': 'user', 'content': 'I am traveling to Spain next week!'}, {'role': 'assistant', 'content': "That's exciting! Spain is a beautiful country with so much to offer. Do you have any specific cities or regions you'll be visiting? I can help with travel tips, local attractions, food recommendations, or anything else you might need!"}]
# You mentioned that you are traveling to Spain next week! Is there anything specific you'd like to know or prepare for your trip?
